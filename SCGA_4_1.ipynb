# %%
import rasterio

# %%
band2 = rasterio.open('C:/Users/RAMBABU/Geopandas/T44QRF_20220427T044649_B02_20m.jp2')#blue band

# %%
band3 = rasterio.open('C:/Users/RAMBABU/Geopandas/T44QRF_20220427T044649_B03_20m.jp2')#green band

# %%
band4 = rasterio.open('C:/Users/RAMBABU/Geopandas/T44QRF_20220427T044649_B04_20m.jp2')#red band

# %%
band5 = rasterio.open('C:/Users/RAMBABU/Geopandas/T44QRF_20220427T044649_B05_20m.jp2')#near red band

# %%
band2.shape, band2.height, band2.count, band2.crs, band2.crs.linear_units, band2.bounds, band2.indexes, band2.meta
# Out:
# ((5490, 5490),
#  5490,
#  1,
#  CRS.from_epsg(32644),
#  'metre',
#  BoundingBox(left=799980.0, bottom=1990200.0, right=909780.0, top=2100000.0),
#  (1,),
#  {'driver': 'JP2OpenJPEG',
#   'dtype': 'uint16',
#   'nodata': None,
#   'width': 5490,
#   'height': 5490,
#   'count': 1,
#   'crs': CRS.from_epsg(32644),
#   'transform': Affine(20.0, 0.0, 799980.0,
#          0.0, -20.0, 2100000.0)})

# %%
from rasterio.plot import show_hist
show_hist(band2, bins=20, lw=0.0, stacked=False, alpha=0.3,
        histtype='stepfilled', title="Histogram")

# %%
from rasterio.plot import show_hist
show_hist(band3, bins=20, lw=0.0, stacked=False, alpha=0.3,
        histtype='stepfilled', title="Histogram")

# %%
from rasterio.plot import show_hist
show_hist(band4, bins=20, lw=0.0, stacked=False, alpha=0.3,
        histtype='stepfilled', title="Histogram")

# %%
from rasterio.plot import show_hist
show_hist(band5, bins=20, lw=0.0, stacked=False, alpha=0.3,
        histtype='stepfilled', title="Histogram")

# %%
import rasterio
from matplotlib import pyplot
pyplot.imshow(band2.read(1), cmap='terrain')
pyplot.show()

# %%
import rasterio
from matplotlib import pyplot
pyplot.imshow(band3.read(1), cmap='terrain')
pyplot.show()

# %%
import rasterio
from matplotlib import pyplot
pyplot.imshow(band4.read(1), cmap='terrain')
pyplot.show()

# %%
import rasterio
from matplotlib import pyplot
pyplot.imshow(band5.read(1), cmap='terrain')
pyplot.show()

# %%
#plotting at a time all bands
import matplotlib.pyplot as plt
fig, (ax1,ax2,ax3,ax4) = plt.subplots(1,4,figsize=(12,4))
plot.show(band2, ax=ax1, cmap='Blues')
plot.show(band3, ax=ax2, cmap='Greens')
plot.show(band4, ax=ax3, cmap='Reds')
plot.show(band5, ax=ax4, cmap='Greens')
fig.tight_layout()

# %%
band2.read(1),band3.read(1), band4.read(1)
# Out:
# (array([[1681, 1602, 1557, ..., 1502, 1481, 1505],
#         [1603, 1613, 1564, ..., 1492, 1454, 1499],
#         [1631, 1592, 1434, ..., 1471, 1474, 1482],
#         ...,
#         [1492, 1498, 1509, ..., 1761, 1658, 1772],
#         [1505, 1536, 1509, ..., 2457, 1814, 1727],
#         [1509, 1447, 1519, ..., 3293, 2510, 2525]], dtype=uint16),
#  array([[1910, 1858, 1800, ..., 1532, 1515, 1521],
#         [1878, 1837, 1841, ..., 1538, 1524, 1561],
#         [1939, 1869, 1710, ..., 1527, 1530, 1504],
#         ...,
#         [1429, 1417, 1423, ..., 1773, 1610, 1632],
#         [1417, 1460, 1414, ..., 2692, 2037, 1653],
#         [1449, 1391, 1440, ..., 3084, 2963, 2511]], dtype=uint16),
#  array([[2331, 2241, 2128, ..., 1571, 1573, 1535],
#         [2314, 2251, 2136, ..., 1533, 1537, 1592],
#         [2448, 2303, 1800, ..., 1577, 1544, 1529],
#         ...,
#         [1419, 1385, 1406, ..., 2025, 1764, 1597],
#         [1408, 1417, 1386, ..., 2807, 2519, 1773],
# ...

# %%
band2.read(1),band3.read(1), band4.read(1)
# Out:
# (array([[1681, 1602, 1557, ..., 1502, 1481, 1505],
#         [1603, 1613, 1564, ..., 1492, 1454, 1499],
#         [1631, 1592, 1434, ..., 1471, 1474, 1482],
#         ...,
#         [1492, 1498, 1509, ..., 1761, 1658, 1772],
#         [1505, 1536, 1509, ..., 2457, 1814, 1727],
#         [1509, 1447, 1519, ..., 3293, 2510, 2525]], dtype=uint16),
#  array([[1910, 1858, 1800, ..., 1532, 1515, 1521],
#         [1878, 1837, 1841, ..., 1538, 1524, 1561],
#         [1939, 1869, 1710, ..., 1527, 1530, 1504],
#         ...,
#         [1429, 1417, 1423, ..., 1773, 1610, 1632],
#         [1417, 1460, 1414, ..., 2692, 2037, 1653],
#         [1449, 1391, 1440, ..., 3084, 2963, 2511]], dtype=uint16),
#  array([[2331, 2241, 2128, ..., 1571, 1573, 1535],
#         [2314, 2251, 2136, ..., 1533, 1537, 1592],
#         [2448, 2303, 1800, ..., 1577, 1544, 1529],
#         ...,
#         [1419, 1385, 1406, ..., 2025, 1764, 1597],
#         [1408, 1417, 1386, ..., 2807, 2519, 1773],
# ...

# %%
Truecolor = rio.open('C:/Users/RAMBABU/Geopandas/trucolor.tiff','w',driver='Gtiff',
                    width= band2.width, height= band2.height,
                    count=3,
                    crs = band2.crs,
                    transform = band2.transform,
                    dtype = 'uint16'
                    )
Truecolor.write(band2.read(1),3)#blue
Truecolor.write(band3.read(1),2)#green
Truecolor.write(band4.read(1),1)#red
Truecolor.close()

# %%
truecolor = rasterio.open('C:/Users/RAMBABU/Geopandas/trucolor.tiff')

# %%
import rasterio
from matplotlib import pyplot
pyplot.imshow(truecolor.read(1), cmap='terrain')
pyplot.show()

# %%
band8A = rasterio.open('C:/Users/RAMBABU/Geopandas/T44QRF_20220427T044649_B8A_20m.jp2')#narrow NIR

falsecolor = rio.open('C:/Users/RAMBABU/Geopandas/falsecolor.tiff','w',driver='Gtiff',
                    width= band2.width, height= band2.height,
                    count=3,
                    crs = band2.crs,
                    transform = band2.transform,
                    dtype = 'uint16'
                    )
falsecolor.write(band3.read(1),3)#blue
falsecolor.write(band4.read(1),2)#green
falsecolor.write(band8A.read(1),1)#red
falsecolor.close()

# %%
red = band4.read()
nir = band8A.read()

ndvi = (nir.astype(float)-red.astype(float)/(nir+red))

meta = band4.meta
meta.update(driver='GTiff')
meta.update(dtype= rio.float32)

with rio.open('NDVI.tiff','w', **meta) as dst:
    dst.write(ndvi.astype(rio.float32))

# %%
NDVI = rasterio.open('C:/Users/RAMBABU/Geopandas/NDVI.tiff')

# %%
import rasterio
from matplotlib import pyplot
pyplot.imshow(NDVI.read(1), cmap='gray')
pyplot.show()

# %%
from rasterio.plot import show_hist
show_hist(NDVI, bins=20, lw=0.0, stacked=False, alpha=0.3,
        histtype='stepfilled', title="Histogram")

# %%
NDVI.read(1)
# Out:
# array([[3672.6118, 3604.6167, 3579.6272, ..., 1633.5099, 1597.5039,
#         1557.5037],
#        [3601.609 , 3606.6157, 3664.6318, ..., 1571.5062, 1571.5056,
#         1611.5032],
#        [3869.6125, 3836.625 , 4428.711 , ..., 1617.5065, 1578.5056,
#         1585.5092],
#        ...,
#        [1413.4991, 1392.5015, 1401.4993, ..., 2465.549 , 2314.5676,
#         1737.5211],
#        [1447.507 , 1406.4982, 1380.4991, ..., 2509.4722, 3026.546 ,
#         2454.5806],
#        [1430.5033, 1414.5068, 1402.5011, ..., 2738.4778, 3494.5044,
#         3540.557 ]], dtype=float32)

# %%
NDVI.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'float32',
#  'nodata': None,
#  'width': 5490,
#  'height': 5490,
#  'count': 1,
#  'crs': CRS.from_epsg(32644),
#  'transform': Affine(20.0, 0.0, 799980.0,
#         0.0, -20.0, 2100000.0)}

# %%
import rasterio

from rasterio.plot import show

from rasterio.plot import show_hist

from rasterio.mask import mask

from shapely.geometry import box

import geopandas as gpd

from fiona.crs import from_epsg

import pycrs

# %%
# Filepaths
truecolor = rasterio.open('C:/Users/RAMBABU/Geopandas/trucolor.tiff')

# %%
import rasterio
from matplotlib import pyplot
pyplot.imshow(truecolor.read(1), cmap='terrain')
pyplot.show()

# %%
truecolor.crs
# Out:
# CRS.from_epsg(32644)

# %%
import fiona
import rasterio
import rasterio.mask

with fiona.open("sub.shp", "r") as shapefile:
    shapes = [feature["geometry"] for feature in shapefile]

# %%
    out_image, out_transform = rasterio.mask.mask(band2, shapes, crop=True)
    out_meta = band2.meta

# %%
out_meta.update({"driver": "GTiff",
                 "height": out_image.shape[1],
                 "width": out_image.shape[2],
                 "transform": out_transform})

with rasterio.open("band3.byte.masked.tif", "w", **out_meta) as dest:
    dest.write(out_image)
