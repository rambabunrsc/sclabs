# %%
import rasterio
from matplotlib import pyplot
data = rasterio.open("Kanyakumari_143054_subset.tif")
pyplot.imshow(src.read(1), cmap='pink')
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11300\3931639919.py in <cell line: 4>()
#       2 from matplotlib import pyplot
#       3 data = rasterio.open("Kanyakumari_143054_subset.tif")
# ----> 4 pyplot.imshow(src.read(1), cmap='pink')
#       5 pyplot.show()
#
# NameError: name 'src' is not defined

# %%
import rasterio
from matplotlib import pyplot
data = rasterio.open("Kanyakumari_143054_subset.tif")
pyplot.imshow(data.read(1), cmap='hsv,256')
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19580\1091953348.py in <cell line: 4>()
#       2 from matplotlib import pyplot
#       3 data = rasterio.open("Kanyakumari_143054_subset.tif")
# ----> 4 pyplot.imshow(data.read(1), cmap='hsv,256')
#       5 pyplot.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     457                 "parameter will become keyword-only %(removal)s.",
#     458                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459         return func(*args, **kwargs)
#     460
#     461     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# ...

# %%
import rasterio
from matplotlib import pyplot
data = rasterio.open("Kanyakumari_143054_subset.tif")
pyplot.imshow(data.read(1), cmap='hsv,256')
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19580\94390233.py in <cell line: 4>()
#       2 from matplotlib import pyplot
#       3 data = rasterio.open("Kanyakumari_143054_subset.tif")
# ----> 4 pyplot.imshow(data.read(1), cmap='hsv,256')
#       5 pyplot.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     457                 "parameter will become keyword-only %(removal)s.",
#     458                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459         return func(*args, **kwargs)
#     460
#     461     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# ...

# %%
import rasterio
from matplotlib import pyplot
data = rasterio.open("Kanyakumari_143054_subset.tif")
pyplot.imshow(data.read(1), cmap='hsv,3')
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19580\1293093629.py in <cell line: 4>()
#       2 from matplotlib import pyplot
#       3 data = rasterio.open("Kanyakumari_143054_subset.tif")
# ----> 4 pyplot.imshow(data.read(1), cmap='hsv,3')
#       5 pyplot.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*args, **kwargs)
#     457                 "parameter will become keyword-only %(removal)s.",
#     458                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 459         return func(*args, **kwargs)
#     460
#     461     # Don't modify *func*'s signature, as boilerplate.py needs it.
#
# ...

# %%
import rasterio
from matplotlib import pyplot
data = rasterio.open("Kanyakumari_143054_subset.tif")
pyplot.imshow(data.read(1), cmap='hsv')
pyplot.show()

# %%
data.crs
# Out:
# CRS.from_epsg(32643)

# %%
data.width
data.height
data.crs
data.count
type(data)
data_meta=data.meta
print(data_meta)
# Out:
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 2000, 'height': 1000, 'count': 6, 'crs': CRS.from_epsg(32643), 'transform': Affine(30.0, 0.0, 737505.0,
#        0.0, -30.0, 910155.0)}

# %%
data.width
data.height
data.crs
data.count
# Out:
# 6

# %%
data.width
# Out:
# 2000

# %%
data.height
# Out:
# 1000

# %%
data.crs
# Out:
# CRS.from_epsg(32643)

# %%
data.count
# Out:
# 6

# %%
type(data)
data_meta=data.meta
print(data_meta)
# Out:
# {'driver': 'GTiff', 'dtype': 'float32', 'nodata': 0.0, 'width': 2000, 'height': 1000, 'count': 6, 'crs': CRS.from_epsg(32643), 'transform': Affine(30.0, 0.0, 737505.0,
#        0.0, -30.0, 910155.0)}

# %%
show(data,cmap='RdYlGn')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19580\1667470473.py in <cell line: 1>()
# ----> 1 show(data,cmap='RdYlGn')
#
# NameError: name 'show' is not defined

# %%
from rasterio.plot
show_hist(data, bins=20, lw=0.0, stacked=False, alpha=0.3,
        histtype='stepfilled', title="Histogram")
# Out:
#   File "C:\Users\RAMBABU\AppData\Local\Temp\ipykernel_19580\2363330591.py", line 1
#     from rasterio.plot
#                       ^
# SyntaxError: invalid syntax

# %%
from rasterio.plot import show_hist
show_hist(data, bins=20, lw=0.0, stacked=False, alpha=0.3,
        histtype='stepfilled', title="Histogram")

# %%
with rio.open('Kanyakumari_143054_subset.tif') as red_src:
    data = red_src.read(1, masked=True)
    data = red_src.profile
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19580\2771518148.py in <cell line: 1>()
# ----> 1 with rio.open('Kanyakumari_143054_subset.tif') as red_src:
#       2     data = red_src.read(1, masked=True)
#       3     data = red_src.profile
#
# NameError: name 'rio' is not defined

# %%
with rio.open('Kanyakumari_143054_subset.tif') as red_src:
    red_data = red_src.read(1, masked=True)
    red_meta = red_src.profile
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19580\1659452350.py in <cell line: 1>()
# ----> 1 with rio.open('Kanyakumari_143054_subset.tif') as red_src:
#       2     red_data = red_src.read(1, masked=True)
#       3     red_meta = red_src.profile
#
# NameError: name 'rio' is not defined

# %%
glist = glob( "*.tif")
glist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19580\2038540958.py in <cell line: 1>()
# ----> 1 glist = glob( "*.tif")
#       2 glist
#
# NameError: name 'glob' is not defined

# %%
glist = glob( "*.jp2")
glist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19580\2608262162.py in <cell line: 1>()
# ----> 1 glist = glob( "*.jp2")
#       2 glist
#
# NameError: name 'glob' is not defined

# %%
import rioxarray
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19580\1200407846.py in <cell line: 1>()
# ----> 1 import rioxarray
#
# ModuleNotFoundError: No module named 'rioxarray'

# %%
import rioxarray

# %%
print(data)
# Out:
# <open DatasetReader name='Kanyakumari_143054_subset.tif' mode='r'>

# %%
data_1 = rioxarray.open_rasterio("Kanyakumari_143054_subset.tif")

# %%
print(data_1)
# Out:
# <xarray.DataArray (band: 6, y: 1000, x: 2000)>
# [12000000 values with dtype=float32]
# Coordinates:
#   * band         (band) int32 1 2 3 4 5 6
#   * x            (x) float64 7.375e+05 7.376e+05 ... 7.975e+05 7.975e+05
#   * y            (y) float64 9.101e+05 9.101e+05 ... 8.802e+05 8.802e+05
#     spatial_ref  int32 0
# Attributes:
#     AREA_OR_POINT:        Area
#     TIFFTAG_XRESOLUTION:  1
#     TIFFTAG_YRESOLUTION:  1
#     LAYER_TYPE:           athematic
#     OVERVIEWS_ALGORITHM:  ErdasBino3
#     _FillValue:           0.0
#     scale_factor:         1.0
#     add_offset:           0.0
#     long_name:            ('Layer_1', 'Layer_2', 'Layer_3', 'Layer_4', 'Layer...

# %%
print(type(rgb_data_1))
print(rgb_data_1.shape)
print(rgb_data_1.values)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19580\3104429097.py in <cell line: 1>()
# ----> 1 print(type(rgb_data_1))
#       2 print(rgb_data_1.shape)
#       3 print(rgb_data_1.values)
#
# NameError: name 'rgb_data_1' is not defined

# %%
print(type(data_1))
print(data_1.shape)
print(data_1.values)
# Out:
# <class 'xarray.core.dataarray.DataArray'>
# (6, 1000, 2000)
# [[[7.0097647  6.9914455  6.9992967  ... 6.563566   6.322802   6.215505  ]
#   [6.98752    6.9744353  6.9835944  ... 6.8134894  6.3790674  6.2927065 ]
#   [7.028084   6.9705095  6.9626584  ... 7.073881   6.843585   6.537396  ]
#   ...
#   [6.2966323  6.2691536  6.3136425  ... 7.9204807  7.882534   7.8629065 ]
#   [6.3136425  6.273079   6.33327    ... 7.911321   7.893002   7.911321  ]
#   [6.2966323  6.3136425  6.2796216  ... 7.917864   7.885151   7.9100127 ]]
#
#  [[4.336665   4.288437   4.236592   ... 5.5761247  5.12881    5.063702  ]
#   [4.4234753  4.341488   4.316168   ... 6.3851495  5.3325734  5.180655  ]
#   [4.5199313  4.417447   4.3812757  ... 6.5334506  6.1066327  5.724426  ]
#   ...
#   [3.4974978  3.484235   3.4830294  ... 5.0178857  4.980509   4.9612174 ]
#   [3.484235   3.4938807  3.5336688  ... 5.0082397  4.980509   4.979303  ]
#   [3.5035262  3.5228174  3.5264347  ... 5.0022116  4.980509   4.979303  ]]
#
# ...

# %%
print(data_1.attrs)
# Out:
# {'AREA_OR_POINT': 'Area', 'TIFFTAG_XRESOLUTION': 1, 'TIFFTAG_YRESOLUTION': 1, 'LAYER_TYPE': 'athematic', 'OVERVIEWS_ALGORITHM': 'ErdasBino3', '_FillValue': 0.0, 'scale_factor': 1.0, 'add_offset': 0.0, 'long_name': ('Layer_1', 'Layer_2', 'Layer_3', 'Layer_4', 'Layer_5', 'Layer_6')}

# %%
data_1_band_1 = data_1.sel(band=1)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19580\2166830960.py in <cell line: 1>()
# ----> 1 show(data_1_band_1)
#
# NameError: name 'show' is not defined

# %%
data_1_band_1.plot.imshow(cmap="Greys")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19580\250126554.py in <cell line: 1>()
# ----> 1 data_1_band_1.plot.imshow(cmap="Greys")
#
# ~\anaconda3\lib\site-packages\xarray\plot\plot.py in plotmethod(_PlotMethods_obj, x, y, figsize, size, aspect, ax, row, col, col_wrap, xincrease, yincrease, add_colorbar, add_labels, vmin, vmax, cmap, colors, center, robust, extend, levels, infer_intervals, subplot_kws, cbar_ax, cbar_kwargs, xscale, yscale, xticks, yticks, xlim, ylim, norm, **kwargs)
#    1308         for arg in ["_PlotMethods_obj", "newplotfunc", "kwargs"]:
#    1309             del allargs[arg]
# -> 1310         return newplotfunc(**allargs)
#    1311
#    1312     # Add to class _PlotMethods
#
# ...

# %%
data_1_band_1.plot.imshow(figsize=(9,7), cmap="Greys")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19580\3488628269.py in <cell line: 1>()
# ----> 1 data_1_band_1.plot.imshow(figsize=(9,7), cmap="Greys")
#
# ~\anaconda3\lib\site-packages\xarray\plot\plot.py in plotmethod(_PlotMethods_obj, x, y, figsize, size, aspect, ax, row, col, col_wrap, xincrease, yincrease, add_colorbar, add_labels, vmin, vmax, cmap, colors, center, robust, extend, levels, infer_intervals, subplot_kws, cbar_ax, cbar_kwargs, xscale, yscale, xticks, yticks, xlim, ylim, norm, **kwargs)
#    1308         for arg in ["_PlotMethods_obj", "newplotfunc", "kwargs"]:
#    1309             del allargs[arg]
# -> 1310         return newplotfunc(**allargs)
#    1311
#    1312     # Add to class _PlotMethods
#
# ...

# %%
data_1_band_2 = data_1.sel(band=2)

# %%
data_1_band_2.plot.imshow(figsize=(9,7), cmap="Greys")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19580\85991731.py in <cell line: 1>()
# ----> 1 data_1_band_2.plot.imshow(figsize=(9,7), cmap="Greys")
#
# ~\anaconda3\lib\site-packages\xarray\plot\plot.py in plotmethod(_PlotMethods_obj, x, y, figsize, size, aspect, ax, row, col, col_wrap, xincrease, yincrease, add_colorbar, add_labels, vmin, vmax, cmap, colors, center, robust, extend, levels, infer_intervals, subplot_kws, cbar_ax, cbar_kwargs, xscale, yscale, xticks, yticks, xlim, ylim, norm, **kwargs)
#    1308         for arg in ["_PlotMethods_obj", "newplotfunc", "kwargs"]:
#    1309             del allargs[arg]
# -> 1310         return newplotfunc(**allargs)
#    1311
#    1312     # Add to class _PlotMethods
#
# ...

# %%
data_1_band_2.plot.imshow(figsize=(9,7), cmap="hsv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19580\3726615307.py in <cell line: 1>()
# ----> 1 data_1_band_2.plot.imshow(figsize=(9,7), cmap="hsv")
#
# ~\anaconda3\lib\site-packages\xarray\plot\plot.py in plotmethod(_PlotMethods_obj, x, y, figsize, size, aspect, ax, row, col, col_wrap, xincrease, yincrease, add_colorbar, add_labels, vmin, vmax, cmap, colors, center, robust, extend, levels, infer_intervals, subplot_kws, cbar_ax, cbar_kwargs, xscale, yscale, xticks, yticks, xlim, ylim, norm, **kwargs)
#    1308         for arg in ["_PlotMethods_obj", "newplotfunc", "kwargs"]:
#    1309             del allargs[arg]
# -> 1310         return newplotfunc(**allargs)
#    1311
#    1312     # Add to class _PlotMethods
#
# ...

# %%
data_1_band_4 = data_1.sel(band=4)

# %%
data_1_band_4.plot.imshow(figsize=(9,7), cmap="hsv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19580\1829002208.py in <cell line: 1>()
# ----> 1 data_1_band_4.plot.imshow(figsize=(9,7), cmap="hsv")
#
# ~\anaconda3\lib\site-packages\xarray\plot\plot.py in plotmethod(_PlotMethods_obj, x, y, figsize, size, aspect, ax, row, col, col_wrap, xincrease, yincrease, add_colorbar, add_labels, vmin, vmax, cmap, colors, center, robust, extend, levels, infer_intervals, subplot_kws, cbar_ax, cbar_kwargs, xscale, yscale, xticks, yticks, xlim, ylim, norm, **kwargs)
#    1308         for arg in ["_PlotMethods_obj", "newplotfunc", "kwargs"]:
#    1309             del allargs[arg]
# -> 1310         return newplotfunc(**allargs)
#    1311
#    1312     # Add to class _PlotMethods
#
# ...

# %%
data_1.plot.imshow(figsize=(9,7))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19580\3851379968.py in <cell line: 1>()
# ----> 1 data_1.plot.imshow(figsize=(9,7))
#
# ~\anaconda3\lib\site-packages\xarray\plot\plot.py in plotmethod(_PlotMethods_obj, x, y, figsize, size, aspect, ax, row, col, col_wrap, xincrease, yincrease, add_colorbar, add_labels, vmin, vmax, cmap, colors, center, robust, extend, levels, infer_intervals, subplot_kws, cbar_ax, cbar_kwargs, xscale, yscale, xticks, yticks, xlim, ylim, norm, **kwargs)
#    1308         for arg in ["_PlotMethods_obj", "newplotfunc", "kwargs"]:
#    1309             del allargs[arg]
# -> 1310         return newplotfunc(**allargs)
#    1311
#    1312     # Add to class _PlotMethods
#
# ...

# %%
data_1_band_6 = data_1.sel(band=6)

# %%
data_1_band_6.plot.imshow(figsize=(9,7), cmap="hsv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19580\2676513675.py in <cell line: 1>()
# ----> 1 data_1_band_6.plot.imshow(figsize=(9,7), cmap="hsv")
#
# ~\anaconda3\lib\site-packages\xarray\plot\plot.py in plotmethod(_PlotMethods_obj, x, y, figsize, size, aspect, ax, row, col, col_wrap, xincrease, yincrease, add_colorbar, add_labels, vmin, vmax, cmap, colors, center, robust, extend, levels, infer_intervals, subplot_kws, cbar_ax, cbar_kwargs, xscale, yscale, xticks, yticks, xlim, ylim, norm, **kwargs)
#    1308         for arg in ["_PlotMethods_obj", "newplotfunc", "kwargs"]:
#    1309             del allargs[arg]
# -> 1310         return newplotfunc(**allargs)
#    1311
#    1312     # Add to class _PlotMethods
#
# ...
