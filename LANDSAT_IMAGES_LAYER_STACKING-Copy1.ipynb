# %%
import rasterio
from os import listdir
from os.path import isfile, join

# %%
path = 'D:/rambabu_r@nrsc.gov.in/STUDY/MTECH/IIST GeoInformatics Text books/1 SEM\RS/Labs/LST/L8'

# %%
files = [f for f in listdir(path) if isfile(join(path,f))]
print(files[10:16])
# Out:
# ['LC08_L1TP_144048_20221031_20221108_02_T1_B2.TIF', 'LC08_L1TP_144048_20221031_20221108_02_T1_B3.TIF', 'LC08_L1TP_144048_20221031_20221108_02_T1_B4.TIF', 'LC08_L1TP_144048_20221031_20221108_02_T1_B5.TIF', 'LC08_L1TP_144048_20221031_20221108_02_T1_B6_10_TIR.TIF', 'LC08_L1TP_144048_20221031_20221108_02_T1_B7_11_TIR.TIF']

# %%
# reading the metadata of first file
with rasterio.open(path+'/'+files[10]) as src0:
    meta = src0.meta
    meta.update(count = len(files[10:16]))

# %%
#read each layer and write it to stack
with rasterio.open('stack_LST_1.tiff', "w",**meta) as dst:
        for id, layer in enumerate (files[10:16], start = 1):
            print(path+'/'+layer)
            with rasterio.open(path+'/'+layer) as src1:
                dst.write_band(id, src1.read(1))
                print('stacked.tiff')
stack = rasterio.open('stack_LST_1.tiff')
# Out:
# D:/rambabu_r@nrsc.gov.in/STUDY/MTECH/IIST GeoInformatics Text books/1 SEM\RS/Labs/LST/L8/LC08_L1TP_144048_20221031_20221108_02_T1_B2.TIF
# stacked.tiff
# D:/rambabu_r@nrsc.gov.in/STUDY/MTECH/IIST GeoInformatics Text books/1 SEM\RS/Labs/LST/L8/LC08_L1TP_144048_20221031_20221108_02_T1_B3.TIF
# stacked.tiff
# D:/rambabu_r@nrsc.gov.in/STUDY/MTECH/IIST GeoInformatics Text books/1 SEM\RS/Labs/LST/L8/LC08_L1TP_144048_20221031_20221108_02_T1_B4.TIF
# stacked.tiff
# D:/rambabu_r@nrsc.gov.in/STUDY/MTECH/IIST GeoInformatics Text books/1 SEM\RS/Labs/LST/L8/LC08_L1TP_144048_20221031_20221108_02_T1_B5.TIF
# stacked.tiff
# D:/rambabu_r@nrsc.gov.in/STUDY/MTECH/IIST GeoInformatics Text books/1 SEM\RS/Labs/LST/L8/LC08_L1TP_144048_20221031_20221108_02_T1_B6_10_TIR.TIF
# stacked.tiff
# D:/rambabu_r@nrsc.gov.in/STUDY/MTECH/IIST GeoInformatics Text books/1 SEM\RS/Labs/LST/L8/LC08_L1TP_144048_20221031_20221108_02_T1_B7_11_TIR.TIF
# stacked.tiff

# %%
LST = rasterio.open('stack_LST_1.tiff')

# %%
LST.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'uint16',
#  'nodata': 0.0,
#  'width': 7681,
#  'height': 7841,
#  'count': 6,
#  'crs': CRS.from_epsg(32644),
#  'transform': Affine(30.0, 0.0, 89085.0,
#         0.0, -30.0, 2037015.0)}

# %%
LST.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'uint16',
#  'nodata': 0.0,
#  'width': 7681,
#  'height': 7841,
#  'count': 6,
#  'crs': CRS.from_epsg(32644),
#  'transform': Affine(30.0, 0.0, 89085.0,
#         0.0, -30.0, 2037015.0)}

# %%
import rasterio
from matplotlib import pyplot
pyplot.imshow(LST.read(4), cmap='viridis')

# %%
desc = LST.descriptions
metadata = LST.meta

print('Raster description: {desc}\n'.format(desc=desc))
# Out:
# Raster description: (None, None, None, None, None, None)

# %%
# Open the fourth band in our image - NIR here
nir = LST.read(4).astype(float)
red = LST.read(3).astype(float)
nir.shape
red.shape
# check out the dimensions of the image
# Out:
# (7841, 7681)

# %%
from osgeo import gdal
import rasterio
import numpy as np
import matplotlib.pyplot as plt
dinom = nir+red
numer = nir-red
np.seterr(divide='ignore', invalid='ignore')
# Out:
# {'divide': 'ignore', 'over': 'warn', 'under': 'ignore', 'invalid': 'ignore'}

# %%
nir.flatten().max()
# Out:
# 65535.0

# %%
red.flatten().max()
# Out:
# 54818.0

# %%
65535+54818
# Out:
# 120353

# %%
dinom.flatten().max()
# Out:
# 63125

# %%
numer.flatten().max()
# Out:
# 65535

# %%
ndvi = np.where(dinom==0.0, 0.0, numer/dinom)

# %%
ndvi.flatten().max()
# Out:
# 1.0

# %%
plt.figure()
plt.imshow(ndvi)

# %%
import rasterio
from matplotlib import pyplot
pyplot.imshow(LST.read(1), cmap='hsv')
pyplot.show()

# %%
LST.meta
LST.shape
# Out:
# (7841, 7681)

# %%
import fiona
import rasterio
import rasterio.mask
with fiona.open("ICRISAT.shp", "r") as shapefile:
    shapes = [feature["geometry"] for feature in shapefile]
out_image, out_transform = rasterio.mask.mask(LST, shapes, crop=True)
out_meta = LST.meta
out_meta.update({"driver": "GTiff",
                 "height": out_image.shape[1],
                 "width": out_image.shape[2],
                 "transform": out_transform})

with rasterio.open("LST.byte.masked.tif", "w", **out_meta) as dest:
    dest.write(out_image)
# Out:
# ---------------------------------------------------------------------------
# WindowError                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\rasterio\mask.py in raster_geometry_mask(dataset, shapes, all_touched, invert, crop, pad, pad_width)
#      81     try:
# ---> 82         window = geometry_window(dataset, shapes, pad_x=pad_x, pad_y=pad_y)
#      83
#
# ~\anaconda3\lib\site-packages\rasterio\features.py in geometry_window(dataset, shapes, pad_x, pad_y, north_up, rotated, pixel_precision, boundless)
#     470     if not boundless:
# --> 471         window = window.intersection(raster_window)
#     472
#
# ~\anaconda3\lib\site-packages\rasterio\windows.py in intersection(self, other)
#     773         """
# --> 774         return intersection([self, other])
#
# ~\anaconda3\lib\site-packages\rasterio\windows.py in wrapper(*args, **kwargs)
#     126         if len(args) == 1 and isinstance(args[0], Iterable):
# --> 127             return function(*args[0])
#     128         else:
#
# ~\anaconda3\lib\site-packages\rasterio\windows.py in intersection(*windows)
#     237     """
# --> 238     return functools.reduce(_intersection, windows)
#     239
#
# ~\anaconda3\lib\site-packages\rasterio\windows.py in _intersection(w1, w2)
#     255     else:
# --> 256         raise WindowError(f"Intersection is empty {w1} {w2}")
#     257
#
# WindowError: Intersection is empty Window(col_off=-2967, row_off=67899, width=1, height=1) Window(col_off=0, row_off=0, width=7681, height=7841)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15268\2022896755.py in <cell line: 6>()
#       4 with fiona.open("ICRISAT.shp", "r") as shapefile:
#       5     shapes = [feature["geometry"] for feature in shapefile]
# ----> 6 out_image, out_transform = rasterio.mask.mask(LST, shapes, crop=True)
#       7 out_meta = LST.meta
#       8 out_meta.update({"driver": "GTiff",
#
# ~\anaconda3\lib\site-packages\rasterio\mask.py in mask(dataset, shapes, all_touched, invert, nodata, filled, crop, pad, pad_width, indexes)
#     178             nodata = 0
#     179
# --> 180     shape_mask, transform, window = raster_geometry_mask(
#     181         dataset, shapes, all_touched=all_touched, invert=invert, crop=crop,
#     182         pad=pad, pad_width=pad_width)
#
# ~\anaconda3\lib\site-packages\rasterio\mask.py in raster_geometry_mask(dataset, shapes, all_touched, invert, crop, pad, pad_width)
#      86         # depending on value of crop
#      87         if crop:
# ---> 88             raise ValueError('Input shapes do not overlap raster.')
#      89         else:
#      90             warnings.warn('shapes are outside bounds of raster. '
#
# ValueError: Input shapes do not overlap raster.
